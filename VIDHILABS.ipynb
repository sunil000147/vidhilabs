# %%
for num in range(1, 101):
    if num % 3 == 0 and num % 7 == 0:
        print("FizzBuzz")
    elif num % 3 == 0:
        print("Buzz")
    elif num % 7 == 0:
        print("Fizz")
    else:
        print(num)
# Out:
# 1
# 2
# Buzz
# 4
# 5
# Buzz
# Fizz
# 8
# Buzz
# 10
# 11
# Buzz
# 13
# Fizz
# Buzz
# 16
# 17
# Buzz
# 19
# 20
# FizzBuzz
# 22
# 23
# Buzz
# 25
# 26
# Buzz
# Fizz
# 29
# Buzz
# 31
# 32
# Buzz
# 34
# Fizz
# Buzz
# 37
# 38
# Buzz
# 40
# 41
# FizzBuzz
# 43
# 44
# Buzz
# 46
# 47
# Buzz
# Fizz
# 50
# Buzz
# 52
# 53
# Buzz
# 55
# Fizz
# Buzz
# 58
# 59
# Buzz
# 61
# 62
# FizzBuzz
# 64
# 65
# Buzz
# 67
# 68
# Buzz
# Fizz
# 71
# Buzz
# 73
# 74
# Buzz
# 76
# Fizz
# Buzz
# 79
# 80
# Buzz
# 82
# 83
# FizzBuzz
# 85
# 86
# Buzz
# 88
# 89
# Buzz
# Fizz
# 92
# Buzz
# 94
# 95
# Buzz
# 97
# Fizz
# Buzz
# 100
